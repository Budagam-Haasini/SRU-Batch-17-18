# %% [markdown]
# <a href="https://colab.research.google.com/github/Budagam-Haasini/SRU-Batch-17-18/blob/main/ASSIGNMENT3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
years = [2021,2022,2023,2024,2025]
sales=[100,150,120,200,250]
plt.plot(years,sales)
plt.title("Annual Sales performance")
plt.xlabel("Sales")
plt.show()

# %% [markdown]
# # Assignment 3

# %%
import matplotlib.pyplot as plt
values=[1000,3000,5210,4500]
Categories=["Electronics","Cloths","Home Appliances","Groceries"]
plt.bar(Categories, values, color=["green","blue","pink","yellow"])
plt.title("Category Sales")
plt.xlabel("Categories")
plt.ylabel("Sales")
plt.show()
